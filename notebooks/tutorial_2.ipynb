# %%
# analysis
import numpy as np
import pandas as pd 

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# single-cell
import scanpy as sc
import liana as li

from pathlib import Path
import os 

# seting global dir
cwd=Path.cwd()
if cwd.name == "notebooks":
    os.chdir(cwd.parent.parent) 
os.getcwd()
# Out:
# '/home/maxi7524/repositories'
