# %%
from pathlib import Path
import os 


import mudata as mu
import scanpy as sc


# seting global dir
cwd=Path.cwd()
if cwd.parent.name == "notebooks":
    os.chdir(cwd.parent.parent) 
print(os.getcwd())

# constants
PATH_DATA = Path('data/multimodal')
# Out:
# /home/maxi7524/repositories/project_computational_biology_initial_conditions_pymyboss

# %%
# direct import from module 
from OmniPhysiBoSS.io.mdata._utils.preprocessing.unify_modalities import unify_multimodal_data
from OmniPhysiBoSS.io.mdata._utils.spatial.liana_multimodal_pipeline import run_liana_multimodal_pipeline
from OmniPhysiBoSS.models.base import ModelComponent

# %%
# ładujemy dane 
# create ann data objects
rna = sc.read(PATH_DATA / "sma_rna.h5ad") # 
msi = sc.read(PATH_DATA / "sma_msi.h5ad")
ct = sc.read(PATH_DATA / "sma_deconv.h5ad")

# create multimodal data
# raw_mdata = mu.MuData({'rna':rna, 'msi':msi, 'ct':ct})
# mdata = unify_multimodal_data(raw_mdata, modalities=['rna', 'msi', 'ct'])
raw_mdata = mu.MuData({'rna':rna, 'ct':ct})
mdata = unify_multimodal_data(raw_mdata, modalities=['rna', 'ct'])

result_table_name = 'new_name' # default is liana_res
mdata = run_liana_multimodal_pipeline(mdata, liana_key=result_table_name)
# Out:
# /home/maxi7524/micromamba/envs/OmniPhysiBoss_env/lib/python3.12/site-packages/mudata/_core/mudata.py:1416: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# /home/maxi7524/micromamba/envs/OmniPhysiBoss_env/lib/python3.12/site-packages/mudata/_core/mudata.py:1272: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# /home/maxi7524/micromamba/envs/OmniPhysiBoss_env/lib/python3.12/site-packages/mudata/_core/mudata.py:1416: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# ================================================================================
#            MULTIMODAL DATA HARMONIZATION & DATA LOSS REPORT
# ================================================================================
# [-] Modality Input Size  : 'rna' contains initially 3036 cells.
# [-] Modality Input Size  : 'ct' contains initially 3036 cells.
# [-] Data Retention Audit Trail:
#     -> Modality 'rna': Retained 3036/3036 cells (100.00%). Lost 0 cells.
#     -> Modality 'ct': Retained 3036/3036 cells (100.00%). Lost 0 cells.
# ================================================================================
# --------------------------------------------------------------------------------
# [✓] Harmonization Complete: 3036 cells mutually shared across all layers.
# --------------------------------------------------------------------------------
# /home/maxi7524/micromamba/envs/OmniPhysiBoss_env/lib/python3.12/site-packages/mudata/_core/mudata.py:1272: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# /home/maxi7524/micromamba/envs/OmniPhysiBoss_env/lib/python3.12/site-packages/mudata/_core/mudata.py:1416: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# /home/maxi7524/micromamba/envs/OmniPhysiBoss_env/lib/python3.12/site-packages/mudata/_core/mudata.py:1272: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# [-] Linking initialized main modality 'rna' tracking maps to global root...
# [✓] Linking complete
#
# [-] Scanning spatial density distributions for modality: 'rna'...
#  -> Optimal mathematical bandwidth isolated (k >= 6): 1724.1379310344828
# [-] Computing spatial neighbors into modality 'rna'].obsp['spatial_connectivities']...
# [-] Computing bivariate association scores via 'cosine'...
# /home/maxi7524/micromamba/envs/OmniPhysiBoss_env/lib/python3.12/site-packages/mudata/_core/mudata.py:1416: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# /home/maxi7524/micromamba/envs/OmniPhysiBoss_env/lib/python3.12/site-packages/mudata/_core/mudata.py:1272: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# /home/maxi7524/micromamba/envs/OmniPhysiBoss_env/lib/python3.12/site-packages/anndata/_core/anndata.py:1884: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /home/maxi7524/micromamba/envs/OmniPhysiBoss_env/lib/python3.12/site-packages/legacy_api_wrap/__init__.py:88: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
# /home/maxi7524/micromamba/envs/OmniPhysiBoss_env/lib/python3.12/site-packages/anndata/_core/anndata.py:1884: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /home/maxi7524/micromamba/envs/OmniPhysiBoss_env/lib/python3.12/site-packages/anndata/_core/anndata.py:1884: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /home/maxi7524/micromamba/envs/OmniPhysiBoss_env/lib/python3.12/site-packages/liana/method/_pipe_utils/_pre.py:135: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`. Example key collisions generated by the make_index_unique algorithm: ['Gm16701-1', 'Pakap-1', 'Fam220a-1', 'Gm16499-1', 'Gm35558-1']
# [✓] Local bivariate metrics mapped to mdata['rna'].uns['new_name']
# /home/maxi7524/micromamba/envs/OmniPhysiBoss_env/lib/python3.12/site-packages/mudata/_core/mudata.py:1416: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# /home/maxi7524/micromamba/envs/OmniPhysiBoss_env/lib/python3.12/site-packages/mudata/_core/mudata.py:1272: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.

# %%
mdata.uns[result_table_name]
# Out:
# AnnData object with n_obs × n_vars = 3036 × 409
#     obs: 'rna:in_tissue', 'rna:array_row', 'rna:array_col', 'rna:x', 'rna:y', 'rna:lesion', 'rna:region', 'rna:n_genes_by_counts', 'rna:log1p_n_genes_by_counts', 'rna:total_counts', 'rna:log1p_total_counts', 'rna:pct_counts_in_top_50_genes', 'rna:pct_counts_in_top_100_genes', 'rna:pct_counts_in_top_200_genes', 'rna:pct_counts_in_top_500_genes', 'rna:total_counts_mt', 'rna:log1p_total_counts_mt', 'rna:pct_counts_mt', 'rna:n_genes', 'rna:n_counts', 'ct:in_tissue', 'ct:array_row', 'ct:array_col', 'ct:x', 'ct:y', 'ct:lesion', 'ct:region', 'ct:n_genes_by_counts', 'ct:log1p_n_genes_by_counts', 'ct:total_counts', 'ct:log1p_total_counts', 'ct:pct_counts_in_top_50_genes', 'ct:pct_counts_in_top_100_genes', 'ct:pct_counts_in_top_200_genes', 'ct:pct_counts_in_top_500_genes', 'ct:total_counts_mt', 'ct:log1p_total_counts_mt', 'ct:pct_counts_mt', 'ct:n_genes', 'ct:n_counts', 'ct:uniform_density', 'ct:rna_count_based_density'
#     var: 'ligand', 'receptor', 'ligand_means', 'ligand_props', 'receptor_means', 'receptor_props', 'morans', 'morans_pvals', 'mean', 'std'
#     uns: 'lesion_colors', 'log1p', 'region_colors', 'spatial'
#     obsm: 'spatial'
#     layers: 'cats'
#     obsp: 'spatial_connectivities'

# %% [markdown]
# TEST AREA

# %%
# wynik skryptu profilea
from OmniPhysiBoSS.models.utils.signalling_pathways.archetype_interface_profiler import ArchetypeInterfaceProfiler
# 1. Instantiate the refined component
isolator = ArchetypeInterfaceProfiler()

# 2. Extract input data with your exact result_table_name key
isolator.extract_from_data(
    source_data=mdata, 
    liana_uns_key=result_table_name
)

# 3. Compute filtered boundary elements with explicit parameters
interfaces_profile = isolator(
    top_n_interactions=25, 
    min_prop=0.15,
    ligand_column="ligand",
    receptor_column="receptor"
)
# Out:
# [✓] InterfaceIsolator: Automatically aligned 'ct' layer. Cells: 3036.
# [-] Filtering top 25 spatially active interaction pairs from .var metadata...
#     -> Aligned Archetype 'Oligodendrocytes': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Astrocytes': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Telencephalon projecting excitatory neurons': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Enteric glia': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Telencephalon inhibitory interneurons': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Di- and mesencephalon excitatory neurons': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Microglia': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Cerebellum neurons': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Pericytes': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Non-glutamatergic neuroblasts': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Olfactory inhibitory neurons': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Dentate gyrus granule neurons': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Di- and mesencephalon inhibitory neurons': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Vascular endothelial cells': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Peptidergic neurons': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Olfactory ensheathing cells': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Perivascular macrophages': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Vascular smooth muscle cells': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'MSN4': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Vascular and leptomeningeal cells': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Ependymal cells': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'MSN3': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Spinal cord excitatory neurons': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Hindbrain neurons': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Enteric neurons': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'MSN2': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Cholinergic and monoaminergic neurons': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Peripheral sensory non-peptidergic neurons': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'MSN1': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Oligodendrocyte precursor cells': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Sympathetic noradrenergic neurons': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Spinal cord inhibitory neurons': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Subventricular zone radial glia-like cells': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Satellite glia': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Glutamatergic neuroblasts': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Peripheral sensory peptidergic neurons': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'MSN6': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Choroid epithelial cells': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'MSN5': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'OBDOP1': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Dentate gyrus radial glia-like cells': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'OBDOP2': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Peripheral sensory neurofilament neurons': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Subcommissural organ hypendymal cells': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Sympathetic cholinergic neurons': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'MBDOP2': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'MBDOP1': Isolated 16 ligands, 18 receptors.
#     -> Aligned Archetype 'Schwann cells': Isolated 16 ligands, 18 receptors.
# [✓] Interface isolation completed successfully across all distinct categories.

# %%
len(interfaces_profile['cell_type_interfaces'].keys())
# Out:
# 48

# %%
from OmniPhysiBoSS.models.utils.signalling_pathways.interaction_type_identifier import InteractionTypeIdentifier

# 1. Inicjalizacja instancji komponentu
interaction_identifier = InteractionTypeIdentifier()

# 2. Pobranie bazy OmniPath (wystarczy przekazać mdata jako interfejs)
# mouseconsensus 
interaction_identifier.extract_from_data(source_data=mdata, resource_name="mouseconsensus")

# 3. Uruchomienie kompilacji i znakowania krawędzi
signed_profile = interaction_identifier(
    # source_column="source_genesymbol",
    # target_column="target_genesymbol"
    source_column="ligand",
    target_column="receptor"
)

# 4. Podgląd wygenerowanej ramki danych
import pandas as pd
df_edges = pd.DataFrame(signed_profile["signed_edgelist"])
df_edges
# Out:
# [-] InteractionTypeIdentifier: Fetching intracellular pathway network 'mouseconsensus'...
# [✓] InteractionTypeIdentifier: Successfully cached 3989 raw database entries.
# [-] Reconstructing raw interaction records into signed directed graph topologies...
# [!] Warning: Missing signaling flags. Enforcing default activation signs.
# [✓] Completed sign conversion. Retained 3989 signed directed edges.
#          source       target  sign
# 0          Dll1       Notch1     1
# 1          Dll1       Notch2     1
# 2          Dll1       Notch4     1
# 3          Dll1       Notch3     1
# 4          Nrg2  Erbb2_Erbb3     1
# ...         ...          ...   ...
# 3984  Serpina1a         Lrp1     1
# 3985  Serpina1b         Lrp1     1
# 3986  Serpina1c         Lrp1     1
# 3987  Serpina1d         Lrp1     1
# 3988  Serpina1e         Lrp1     1
#
# [3989 rows x 3 columns]

# %% [markdown]
# wersja dwa

# %%
# =============================================================================
# Cellular Network Unification Component Implementation
# =============================================================================

import networkx as nx
import mudata as mu
from typing import Any, Dict, List, Optional
# from ..base import ModelComponent


class NetworkUnifierComponent(ModelComponent):
    """
    Component responsible for reconstructing and consolidating cell-type specific 
    intracellular signaling subgraphs by tracking path limits between boundaries.
    """

    def __init__(self) -> None:
        """
        Constructor method initialization.
        """
        # Internal parameter and registry allocation
        ## Initialize storage structures for the compiled cell type subgraphs
        self.unified_cell_graphs: Dict[str, List[Dict[str, Any]]] = {}

    def extract_from_data(self, source_data: mu.MuData, context_keys: Dict[str, str]) -> None:
        """
        Abstract declaration compatibility layer (Data extraction handled in execution loop).

        :param source_data: High-dimensional multi-modal container asset.
        :type source_data: mu.MuData
        :param context_keys: Configuration mapping directory registries.
        :type context_keys: Dict[str, str]
        """
        # Pass constraint implementation to preserve interface signature
        pass

    def to_dict(self) -> Dict[str, Any]:
        """
        Serialize compiled cell-type subgraphs into a standard dictionary framework.

        :return: Hierarchical configuration dictionary containing unified network layouts.
        :rtype: Dict[str, Any]
        """
        # Return structured compiled profile registries
        return {
            "unified_cell_graphs": self.unified_cell_graphs
        }

    def __call__(
        self, 
        cell_type_interfaces: Dict[str, Dict[str, List[str]]],
        signed_edgelist: List[Dict[str, Any]],
        target_nodes: List[str],
        max_path_depth: int = 8
    ) -> Dict[str, Any]:
        """
        Orchestrate topological path-finding and network unification across cell types.

        :param cell_type_interfaces: Dictionary mapping cell archetypes to their isolated ligands and receptors.
        :type cell_type_interfaces: Dict[str, Dict[str, List[str]]]
        :param signed_edgelist: Formal edgelist containing source, target, and sign dictionary entries.
        :type signed_edgelist: List[Dict[str, Any]]
        :param target_nodes: Downstream target transcription factor or phenotypic endpoint names.
        :type target_nodes: List[str]
        :param max_path_depth: Maximum allowed edge distance for path traversal, defaults to 8.
        :type max_path_depth: int
        :return: Serialized dictionary tree containing unified network records per cell category.
        :rtype: Dict[str, Any]
        """
        # Reference network compilation phase
        ## Instantiate a global directed graph container to hold OmniPath interactions
        global_graph = nx.DiGraph()
        
        ## Populate the global topology structure with signed edge attributes
        print("[-] NetworkUnifier: Assembling reference global knowledge graph topology...")
        for edge in signed_edgelist:
            global_graph.add_edge(
                edge["source"], 
                edge["target"], 
                sign=edge["sign"]
            )
            
        print(f"[✓] NetworkUnifier: Reference graph compiled with {global_graph.number_of_nodes()} nodes.")

        # Clear historic state configurations
        self.unified_cell_graphs = {}

        # Archetype unification loop
        ## Process each cell type independently to extract its functional signaling network
        for cell_type, interfaces in cell_type_interfaces.items():
            print(f"[-] Compiling optimized intracellular network for archetype: '{cell_type}'...")
            
            ### Isolate sensory inputs specific to this cellular category
            cell_receptors = interfaces.get("receptors", [])
            target_nodes = interfaces.get("ligands", [])

            ### Instantiate an empty directed graph to accumulate valid path traces
            cell_subgraph = nx.DiGraph()

            # Path traversal loop execution
            ## Scan trajectories between every active input receptor and target output endpoint
            for receptor in cell_receptors:
                if receptor not in global_graph:
                    continue
                    
                for target in target_nodes:
                    if target not in global_graph:
                        continue

                    try:
                        ### Extract all simple pathways bounded strictly by the max depth constraint
                        paths = list(nx.all_simple_paths(
                            G=global_graph,
                            source=receptor,
                            target=target,
                            cutoff=max_path_depth
                        ))

                        # Subgraph reconstruction step
                        ## Inject discovered paths back into the cell-specific layout graph
                        for path in paths:
                            for idx in range(len(path) - 1):
                                u = path[idx]
                                v = path[idx + 1]
                                #### Retrieve edge attribute sign directly from the reference topology
                                edge_sign = global_graph[u][v]["sign"]
                                cell_subgraph.add_edge(u, v, sign=edge_sign)

                    except nx.NetworkXNoPath:
                        continue

            # Matrix serialization phase
            ## Format the accumulated cell graph into a standard record dictionary layout
            cell_edges_reporting = []
            for u, v, data in cell_subgraph.edges(data=True):
                cell_edges_reporting.append({
                    "source": u,
                    "target": v,
                    "sign": data["sign"]
                })
                
            self.unified_cell_graphs[cell_type] = cell_edges_reporting
            print(f"    -> Subgraph '{cell_type}' completed: Retained {cell_subgraph.number_of_nodes()} nodes, "
                  f"{cell_subgraph.number_of_edges()} signed krawedzie.")

        print("[✓] Multi-scale network unification workflows completed successfully.")
        return self.to_dict()

# %%
# Krok 1: Izolacja istotnych elementów granicznych komórek
isolator = ArchetypeInterfaceProfiler()
isolator.extract_from_data(source_data=mdata, liana_uns_key=result_table_name)
interfaces_profile = isolator(top_n_interactions=20, min_prop=0.10)

# Krok 2: Pobranie i ustrukturyzowanie bazy OmniPath
db_manager = InteractionTypeIdentifier()
db_manager.extract_from_data(source_data=mdata, resource_name="consensus")
signed_profile = db_manager(source_column="ligand", target_column="receptor")

# Krok 3: Unifikacja i ograniczenie złożoności sieci do głębokości 6
unifier = NetworkUnifierComponent()
final_pathways_profile = unifier(
    cell_type_interfaces=interfaces_profile["cell_type_interfaces"],
    signed_edgelist=signed_profile["signed_edgelist"],
    target_nodes=["Sna12", "Hand1", "Myc"],  # Przykładowe docelowe czynniki transkrypcyjne
    max_path_depth=100
)

# Kontrola wyjściowej struktury danych dla konkretnej klasy komórkowej
print(final_pathways_profile["unified_cell_graphs"].keys())
# Out:
# [✓] InterfaceIsolator: Automatically aligned 'ct' layer. Cells: 3036.
# [-] Filtering top 20 spatially active interaction pairs from .var metadata...
#     -> Aligned Archetype 'Oligodendrocytes': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Astrocytes': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Telencephalon projecting excitatory neurons': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Enteric glia': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Telencephalon inhibitory interneurons': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Di- and mesencephalon excitatory neurons': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Microglia': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Cerebellum neurons': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Pericytes': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Non-glutamatergic neuroblasts': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Olfactory inhibitory neurons': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Dentate gyrus granule neurons': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Di- and mesencephalon inhibitory neurons': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Vascular endothelial cells': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Peptidergic neurons': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Olfactory ensheathing cells': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Perivascular macrophages': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Vascular smooth muscle cells': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'MSN4': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Vascular and leptomeningeal cells': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Ependymal cells': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'MSN3': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Spinal cord excitatory neurons': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Hindbrain neurons': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Enteric neurons': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'MSN2': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Cholinergic and monoaminergic neurons': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Peripheral sensory non-peptidergic neurons': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'MSN1': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Oligodendrocyte precursor cells': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Sympathetic noradrenergic neurons': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Spinal cord inhibitory neurons': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Subventricular zone radial glia-like cells': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Satellite glia': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Glutamatergic neuroblasts': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Peripheral sensory peptidergic neurons': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'MSN6': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Choroid epithelial cells': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'MSN5': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'OBDOP1': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Dentate gyrus radial glia-like cells': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'OBDOP2': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Peripheral sensory neurofilament neurons': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Subcommissural organ hypendymal cells': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Sympathetic cholinergic neurons': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'MBDOP2': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'MBDOP1': Isolated 12 ligands, 15 receptors.
#     -> Aligned Archetype 'Schwann cells': Isolated 12 ligands, 15 receptors.
# [✓] Interface isolation completed successfully across all distinct categories.
# [-] InteractionTypeIdentifier: Fetching intracellular pathway network 'consensus'...
# [✓] InteractionTypeIdentifier: Successfully cached 4624 raw database entries.
# [-] Reconstructing raw interaction records into signed directed graph topologies...
# [!] Warning: Missing signaling flags. Enforcing default activation signs.
# [✓] Completed sign conversion. Retained 4624 signed directed edges.
# [-] NetworkUnifier: Assembling reference global knowledge graph topology...
# [✓] NetworkUnifier: Reference graph compiled with 2017 nodes.
# [-] Compiling optimized intracellular network for archetype: 'Oligodendrocytes'...
#     -> Subgraph 'Oligodendrocytes' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Astrocytes'...
#     -> Subgraph 'Astrocytes' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Telencephalon projecting excitatory neurons'...
#     -> Subgraph 'Telencephalon projecting excitatory neurons' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Enteric glia'...
#     -> Subgraph 'Enteric glia' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Telencephalon inhibitory interneurons'...
#     -> Subgraph 'Telencephalon inhibitory interneurons' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Di- and mesencephalon excitatory neurons'...
#     -> Subgraph 'Di- and mesencephalon excitatory neurons' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Microglia'...
#     -> Subgraph 'Microglia' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Cerebellum neurons'...
#     -> Subgraph 'Cerebellum neurons' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Pericytes'...
#     -> Subgraph 'Pericytes' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Non-glutamatergic neuroblasts'...
#     -> Subgraph 'Non-glutamatergic neuroblasts' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Olfactory inhibitory neurons'...
#     -> Subgraph 'Olfactory inhibitory neurons' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Dentate gyrus granule neurons'...
#     -> Subgraph 'Dentate gyrus granule neurons' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Di- and mesencephalon inhibitory neurons'...
#     -> Subgraph 'Di- and mesencephalon inhibitory neurons' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Vascular endothelial cells'...
#     -> Subgraph 'Vascular endothelial cells' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Peptidergic neurons'...
#     -> Subgraph 'Peptidergic neurons' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Olfactory ensheathing cells'...
#     -> Subgraph 'Olfactory ensheathing cells' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Perivascular macrophages'...
#     -> Subgraph 'Perivascular macrophages' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Vascular smooth muscle cells'...
#     -> Subgraph 'Vascular smooth muscle cells' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'MSN4'...
#     -> Subgraph 'MSN4' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Vascular and leptomeningeal cells'...
#     -> Subgraph 'Vascular and leptomeningeal cells' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Ependymal cells'...
#     -> Subgraph 'Ependymal cells' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'MSN3'...
#     -> Subgraph 'MSN3' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Spinal cord excitatory neurons'...
#     -> Subgraph 'Spinal cord excitatory neurons' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Hindbrain neurons'...
#     -> Subgraph 'Hindbrain neurons' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Enteric neurons'...
#     -> Subgraph 'Enteric neurons' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'MSN2'...
#     -> Subgraph 'MSN2' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Cholinergic and monoaminergic neurons'...
#     -> Subgraph 'Cholinergic and monoaminergic neurons' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Peripheral sensory non-peptidergic neurons'...
#     -> Subgraph 'Peripheral sensory non-peptidergic neurons' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'MSN1'...
#     -> Subgraph 'MSN1' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Oligodendrocyte precursor cells'...
#     -> Subgraph 'Oligodendrocyte precursor cells' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Sympathetic noradrenergic neurons'...
#     -> Subgraph 'Sympathetic noradrenergic neurons' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Spinal cord inhibitory neurons'...
#     -> Subgraph 'Spinal cord inhibitory neurons' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Subventricular zone radial glia-like cells'...
#     -> Subgraph 'Subventricular zone radial glia-like cells' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Satellite glia'...
#     -> Subgraph 'Satellite glia' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Glutamatergic neuroblasts'...
#     -> Subgraph 'Glutamatergic neuroblasts' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Peripheral sensory peptidergic neurons'...
#     -> Subgraph 'Peripheral sensory peptidergic neurons' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'MSN6'...
#     -> Subgraph 'MSN6' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Choroid epithelial cells'...
#     -> Subgraph 'Choroid epithelial cells' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'MSN5'...
#     -> Subgraph 'MSN5' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'OBDOP1'...
#     -> Subgraph 'OBDOP1' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Dentate gyrus radial glia-like cells'...
#     -> Subgraph 'Dentate gyrus radial glia-like cells' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'OBDOP2'...
#     -> Subgraph 'OBDOP2' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Peripheral sensory neurofilament neurons'...
#     -> Subgraph 'Peripheral sensory neurofilament neurons' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Subcommissural organ hypendymal cells'...
#     -> Subgraph 'Subcommissural organ hypendymal cells' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Sympathetic cholinergic neurons'...
#     -> Subgraph 'Sympathetic cholinergic neurons' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'MBDOP2'...
#     -> Subgraph 'MBDOP2' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'MBDOP1'...
#     -> Subgraph 'MBDOP1' completed: Retained 0 nodes, 0 signed krawedzie.
# [-] Compiling optimized intracellular network for archetype: 'Schwann cells'...
#     -> Subgraph 'Schwann cells' completed: Retained 0 nodes, 0 signed krawedzie.
# [✓] Multi-scale network unification workflows completed successfully.
# dict_keys(['Oligodendrocytes', 'Astrocytes', 'Telencephalon projecting excitatory neurons', 'Enteric glia', 'Telencephalon inhibitory interneurons', 'Di- and mesencephalon excitatory neurons', 'Microglia', 'Cerebellum neurons', 'Pericytes', 'Non-glutamatergic neuroblasts', 'Olfactory inhibitory neurons', 'Dentate gyrus granule neurons', 'Di- and mesencephalon inhibitory neurons', 'Vascular endothelial cells', 'Peptidergic neurons', 'Olfactory ensheathing cells', 'Perivascular macrophages', 'Vascular smooth muscle cells', 'MSN4', 'Vascular and leptomeningeal cells', 'Ependymal cells', 'MSN3', 'Spinal cord excitatory neurons', 'Hindbrain neurons', 'Enteric neurons', 'MSN2', 'Cholinergic and monoaminergic neurons', 'Peripheral sensory non-peptidergic neurons', 'MSN1', 'Oligodendrocyte precursor cells', 'Sympathetic noradrenergic neurons', 'Spinal cord inhibitory neurons', 'Subventricular zone radial glia-like cells', 'Satellite glia', 'Glutamatergic neuroblasts', 'Peripheral sensory peptidergic neurons', 'MSN6', 'Choroid epithelial cells', 'MSN5', 'OBDOP1', 'Dentate gyrus radial glia-like cells', 'OBDOP2', 'Peripheral sensory neurofilament neurons', 'Subcommissural organ hypendymal cells', 'Sympathetic cholinergic neurons', 'MBDOP2', 'MBDOP1', 'Schwann cells'])

# %%
final_pathways_profile['unified_cell_graphs']
# Out:
# {'Oligodendrocytes': [],
#  'Astrocytes': [],
#  'Telencephalon projecting excitatory neurons': [],
#  'Enteric glia': [],
#  'Telencephalon inhibitory interneurons': [],
#  'Di- and mesencephalon excitatory neurons': [],
#  'Microglia': [],
#  'Cerebellum neurons': [],
#  'Pericytes': [],
#  'Non-glutamatergic neuroblasts': [],
#  'Olfactory inhibitory neurons': [],
#  'Dentate gyrus granule neurons': [],
#  'Di- and mesencephalon inhibitory neurons': [],
#  'Vascular endothelial cells': [],
#  'Peptidergic neurons': [],
#  'Olfactory ensheathing cells': [],
#  'Perivascular macrophages': [],
#  'Vascular smooth muscle cells': [],
#  'MSN4': [],
#  'Vascular and leptomeningeal cells': [],
#  'Ependymal cells': [],
#  'MSN3': [],
#  'Spinal cord excitatory neurons': [],
#  'Hindbrain neurons': [],
#  'Enteric neurons': [],
#  'MSN2': [],
#  'Cholinergic and monoaminergic neurons': [],
#  'Peripheral sensory non-peptidergic neurons': [],
#  'MSN1': [],
#  'Oligodendrocyte precursor cells': [],
#  'Sympathetic noradrenergic neurons': [],
#  'Spinal cord inhibitory neurons': [],
#  'Subventricular zone radial glia-like cells': [],
#  'Satellite glia': [],
#  'Glutamatergic neuroblasts': [],
#  'Peripheral sensory peptidergic neurons': [],
#  'MSN6': [],
#  'Choroid epithelial cells': [],
#  'MSN5': [],
#  'OBDOP1': [],
#  'Dentate gyrus radial glia-like cells': [],
#  'OBDOP2': [],
#  'Peripheral sensory neurofilament neurons': [],
#  'Subcommissural organ hypendymal cells': [],
#  'Sympathetic cholinergic neurons': [],
#  'MBDOP2': [],
#  'MBDOP1': [],
#  'Schwann cells': []}
