# %% [markdown]
# PLAN:
# - musimy pokazać ogólne rzeczy które można robić z single cell (czyli jakie analizy itd. trzeba wykonać)
# - następnie omówić w jaki sposób biblioteka to integruje i na co pozwala takie rozwiązanie w jaki sposób to pomaga i czy całość analizy jest dokładniejsza -> dlaczego ???
#
# Do nauczenia
# - bardzo dokładne zrozumienie jak działa analiza single cell, jakie są błędy jak należy postępować itd.
